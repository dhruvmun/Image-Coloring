# %%
import os
import sys
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.pyplot import imshow
from PIL import Image
# %matplotlib inline

# %%
IMG_WIDTH = 32
IMG_HEIGHT = 32
COLOR_CHANNELS = 3

# %%
CONTENT_IMG_PATH = 'content1.jpg'
#content_image = scipy.misc.imread(CONTENT_IMG_PATH)
#content_image = np.reshape(content_image, ((1,IMG_HEIGHT,IMG_WIDTH,COLOR_CHANNELS)))
#imshow(content_image[0])

content_image = Image.open(CONTENT_IMG_PATH).convert('LA')
content_image
# Out:
# <PIL.Image.Image image mode=LA size=625x833 at 0x7F0CAC843B70>

# %%
input_image = content_image.resize((IMG_HEIGHT, IMG_WIDTH))
input_image
# Out:
# <PIL.Image.Image image mode=LA size=32x32 at 0x7F0CD463C390>

# %%
import cnn

# %%
Cnn = cnn.CNN()
output_image = Cnn.forward_prop(input_image)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-a52e9d06c34c> in <module>()
#       1 Cnn = cnn.CNN()
# ----> 2 output_image = Cnn.forward_prop(input_image)
#
# ~/Desktop/AI/coloring/cnn.py in forward_prop(self, image)
#      90         def forward_prop(self,image):
#      91                 self.initialize_parameters()
# ---> 92                 conv_layer1 = self.conv_layer(image, self.parameters['conv_layer1_weights'], self.parameters['conv_layer1_biases'])
#      93                 maxpool1 = self.maxpool(conv_layer1)
#      94                 conv_layer2 = self.conv_layer(maxpool1, self.parameters['conv_layer2_weights'], self.parameters['conv_layer2_biases'])
#
# ~/Desktop/AI/coloring/cnn.py in conv_layer(self, image, filter, bias)
#      38
#      39         def conv_layer(self, image, filter, bias):
# ---> 40                 m,row,col,channels = image.shape
#      41                 nf = filter.shape[3]
#      42                 new_image = np.zeros((m, row-self.filter_size+1, col-self.filter_size+1, nf))
#
# AttributeError: 'Image' object has no attribute 'shape'
