# %%
import os
import sys
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.pyplot import imshow
from PIL import Image
# %matplotlib inline

# %%
IMG_WIDTH = 32
IMG_HEIGHT = 32
COLOR_CHANNELS = 3

# %%
CONTENT_IMG_PATH = 'content1.jpg'
#content_image = scipy.misc.imread(CONTENT_IMG_PATH)
#content_image = np.reshape(content_image, ((1,IMG_HEIGHT,IMG_WIDTH,COLOR_CHANNELS)))
#imshow(content_image[0])

content_image = Image.open(CONTENT_IMG_PATH).convert('L')
content_image
# Out:
# <PIL.Image.Image image mode=L size=625x833 at 0x7F5DBEE3AAC8>

# %%
input_image = content_image.resize((IMG_HEIGHT, IMG_WIDTH))
input_image
# Out:
# <PIL.Image.Image image mode=L size=32x32 at 0x7F5DBEE04278>

# %%
input_image = np.asarray(input_image, dtype='float')
input_image = np.expand_dims(input_image, axis=0)
input_image = input_image.reshape((1,32,32,1))
print(input_image.shape)
# Out:
# (1, 32, 32, 1)

# %%
import cnn

# %%
Cnn = cnn.CNN()
output_image = Cnn.forward_prop(input_image)
# Out:
# (1, 32, 32, 1)
# (1, 32, 32, 32)
# (1, 16, 16, 32)
# (1, 16, 16, 64)
# (1, 8, 8, 64)
# (1, 16, 16, 64)
# (1, 16, 16, 32)
# (1, 32, 32, 32)
# (1, 32, 32, 3)

# %%
imshow(output_image[0])
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
